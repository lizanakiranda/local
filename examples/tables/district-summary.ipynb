# %%
import polars as pl
import polars.selectors as cs
from great_tables import GT, loc, style

from ug2021.data import results

# %%
data = (
    results.districts_wide
    .with_columns(
        pl.col("turnout") / 100
    )
    .select("district", "registered", "valid", "invalid", "total", "turnout", "winner")
    .rename(str.capitalize)
)
data
# Out:
# shape: (146, 7)
# ┌──────────┬────────────┬────────┬─────────┬────────┬──────────┬────────────┐
# │ District ┆ Registered ┆ Valid  ┆ Invalid ┆ Total  ┆ Turnout  ┆ Winner     │
# │ ---      ┆ ---        ┆ ---    ┆ ---     ┆ ---    ┆ ---      ┆ ---        │
# │ str      ┆ i64        ┆ i64    ┆ i64     ┆ i64    ┆ f64      ┆ str        │
# ╞══════════╪════════════╪════════╪═════════╪════════╪══════════╪════════════╡
# │ Abim     ┆ 36539      ┆ 23588  ┆ 875     ┆ 24463  ┆ 0.669504 ┆ Museveni   │
# │ Adjumani ┆ 79364      ┆ 46421  ┆ 2540    ┆ 48961  ┆ 0.616917 ┆ Museveni   │
# │ Agago    ┆ 98354      ┆ 63961  ┆ 2572    ┆ 66533  ┆ 0.676465 ┆ Museveni   │
# │ Alebtong ┆ 115804     ┆ 65620  ┆ 3207    ┆ 68827  ┆ 0.59434  ┆ Museveni   │
# │ Amolatar ┆ 71173      ┆ 51276  ┆ 1908    ┆ 53184  ┆ 0.74725  ┆ Museveni   │
# │ …        ┆ …          ┆ …      ┆ …       ┆ …      ┆ …        ┆ …          │
# │ Terego   ┆ 95118      ┆ 48360  ┆ 4497    ┆ 52857  ┆ 0.555699 ┆ Museveni   │
# │ Tororo   ┆ 268434     ┆ 154503 ┆ 5792    ┆ 160295 ┆ 0.597149 ┆ Museveni   │
# │ Wakiso   ┆ 1154086    ┆ 561500 ┆ 12518   ┆ 574018 ┆ 0.497379 ┆ Kyagulanyi │
# │ Yumbe    ┆ 113855     ┆ 71150  ┆ 4075    ┆ 75225  ┆ 0.660709 ┆ Museveni   │
# │ Zombo    ┆ 123432     ┆ 59906  ┆ 4685    ┆ 64591  ┆ 0.523292 ┆ Museveni   │
# └──────────┴────────────┴────────┴─────────┴────────┴──────────┴────────────┘

# %%
sel_votes = pl.col("Invalid", "Valid")
sel_turnout = pl.col("Total", "Turnout")

table = (
    GT(data)
    .tab_header("District Summary")
    .tab_spanner("The Votes", sel_votes)
    .tab_spanner("Turnout", sel_turnout)
    .cols_label(
        Turnout="Percentage"
    ).data_color(
        columns="Registered",
        palette=[
            "#00A600", "#E6E600", "#E8C32E", "#D69C4E", "#Dc863B", "sienna", "sienna4", "tomato4", "brown"
        ],
        domain=[data["Registered"].min(), data["Registered"].max()]
    )
    # format
    .fmt_integer(pl.col("Registered", "Invalid", "Valid", "Total"))
    .fmt_percent(columns=pl.col("Turnout"), decimals=0)
    # style
    .tab_style(
        style=style.fill(color="palegoldenrod"),
        locations=loc.body(columns=sel_votes),
    )
    .tab_style(
        style=style.fill(color="powderblue"),
        locations=loc.body(columns=sel_turnout),
    )
)
table
# Out:
# GT(_tbl_data=shape: (146, 7)
# ┌──────────┬────────────┬────────┬─────────┬────────┬──────────┬────────────┐
# │ District ┆ Registered ┆ Valid  ┆ Invalid ┆ Total  ┆ Turnout  ┆ Winner     │
# │ ---      ┆ ---        ┆ ---    ┆ ---     ┆ ---    ┆ ---      ┆ ---        │
# │ str      ┆ i64        ┆ i64    ┆ i64     ┆ i64    ┆ f64      ┆ str        │
# ╞══════════╪════════════╪════════╪═════════╪════════╪══════════╪════════════╡
# │ Abim     ┆ 36539      ┆ 23588  ┆ 875     ┆ 24463  ┆ 0.669504 ┆ Museveni   │
# │ Adjumani ┆ 79364      ┆ 46421  ┆ 2540    ┆ 48961  ┆ 0.616917 ┆ Museveni   │
# │ Agago    ┆ 98354      ┆ 63961  ┆ 2572    ┆ 66533  ┆ 0.676465 ┆ Museveni   │
# │ Alebtong ┆ 115804     ┆ 65620  ┆ 3207    ┆ 68827  ┆ 0.59434  ┆ Museveni   │
# │ Amolatar ┆ 71173      ┆ 51276  ┆ 1908    ┆ 53184  ┆ 0.74725  ┆ Museveni   │
# │ …        ┆ …          ┆ …      ┆ …       ┆ …      ┆ …        ┆ …          │
# │ Terego   ┆ 95118      ┆ 48360  ┆ 4497    ┆ 52857  ┆ 0.555699 ┆ Museveni   │
# │ Tororo   ┆ 268434     ┆ 154503 ┆ 5792    ┆ 160295 ┆ 0.597149 ┆ Museveni   │
# │ Wakiso   ┆ 1154086    ┆ 561500 ┆ 12518   ┆ 574018 ┆ 0.497379 ┆ Kyagulanyi │
# │ Yumbe    ┆ 113855     ┆ 71150  ┆ 4075    ┆ 75225  ┆ 0.660709 ┆ Museveni   │
# │ Zombo    ┆ 123432     ┆ 59906  ┆ 4685    ┆ 64591  ┆ 0.523292 ┆ Museveni   │
# └──────────┴────────────┴────────┴─────────┴────────┴──────────┴────────────┘, _body=<great_tables._gt_data.Body object at 0x1164fbb60>, _boxhead=Boxhead([ColInfo(var='District', type=<ColInfoTypeEnum.default: 1>, column_label='District', column_align='left', column_width=None), ColInfo(var='Registered', type=<ColInfoTypeEnum.default: 1>, column_label='Registered', column_align='right', column_width=None), ColInfo(var='Invalid', type=<ColInfoTypeEnum.default: 1>, column_label='Invalid', column_align='right', column_width=None), ColInfo(var='Valid', type=<ColInfoTypeEnum.default: 1>, column_label='Valid', column_align='right', column_width=None), ColInfo(var='Total', type=<ColInfoTypeEnum.default: 1>, column_label='Total', column_align='right', column_width=None), ColInfo(var='Turnout', type=<ColInfoTypeEnum.default: 1>, column_label='Percentage', column_align='right', column_width=None), ColInfo(var='Winner', type=<ColInfoTypeEnum.default: 1>, column_label='Winner', column_align='left', column_width=None)]), _stub=<great_tables._gt_data.Stub object at 0x1164fba10>, _spanners=Spanners([SpannerInfo(spanner_id='The Votes', spanner_level=0, spanner_label='The Votes', spanner_units=None, spanner_pattern=None, vars=['Invalid', 'Valid'], built=None), SpannerInfo(spanner_id='Turnout', spanner_level=0, spanner_label='Turnout', spanner_units=None, spanner_pattern=None, vars=['Total', 'Turnout'], built=None)]), _heading=Heading(title='District Summary', subtitle=None, preheader=None), _stubhead=None, _source_notes=[], _footnotes=[], _styles=[StyleInfo(locname=LocBody(columns='Registered', rows=[0], mask=None), grpname=None, colname='Registered', rownum=0, colnum=None, styles=[CellStyleText(color='#000000', font=None, size=None, align=None, v_align=None, style=None, weight=None, stretch=None, decorate=None, transform=None, whitespace=None), CellStyleFill(color='#1bae00')]), StyleInfo(locname=LocBody(columns='Registered', rows=[1], mask=None), grpname=None, colname='Registered', rownum=1, colnum=None, styles=[CellStyleText(color='#000000', font=None, size=None, align=None, v_align=None, style=None, weight=None, stretch=None, decorate=None, transform=None, whitespace=None), CellStyleFill(color='#5bbf00')]), StyleInfo(locname=LocBody(columns='Registered', rows=[2], mask=None), grpname=None, colname='Registered', rownum=2, colnum=None, styles=[CellStyleText(color='#000000', font=None, size=None, align=None, v_align=None, style=None, weight=None, stretch=None, decorate=None, transform=None, whitespace=None), CellStyleFill(color='#77c700')]), StyleInfo(locname=LocBody(columns='Registered', rows=[3], mask=None), grpname=None, colname='Registered', rownum=3, colnum=None, styles=[CellStyleText(color='#000000', font=None, size=None, align=None, v_align=None, style=None, weight=None, stretch=None, decorate=None, transform=None, whitespace=None), CellStyleFill(color='#91ce00')]), StyleInfo(locname=LocBody(columns='Registered', rows=[4], mask=None), grpname=None, colname='Registered', rownum=4, colnum=None, styles=[CellStyleText(color='#000000', font=None, size=None, align=None, v_align=None, style=None, weight=None, stretch=None, decorate=None, transform=None, whitespace=None), CellStyleFill(color='#4fbc00')]), StyleInfo(locname=LocBody(columns='Registered', rows=[5], mask=None), grpname=None, colname='Registered', rownum=5, colnum=None, styles=[CellStyleText(color='#000000', font=None, size=None, align=None, v_align=None, style=None, weight=None, stretch=None, decorate=None, transform=None, whitespace=None), CellStyleFill(color='#26b100')]), StyleInfo(locname=LocBody(columns='Registered', rows=[6], mask=None), grpname=None, colname='Registered', rownum=6, colnum=None, styles=[CellStyleText(color='#000000', font=None, size=None, align=None, v_align=None, style=None, weight=None, stretch=None, decorate=None, transform=None, whitespace=None), CellStyleFill(color='#69c300')]), StyleInfo(locname=LocBody(columns='Registered', rows=[7], mask=None), grpname ...
